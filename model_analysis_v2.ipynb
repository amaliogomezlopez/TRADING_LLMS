# %% [markdown]
# # 💰 Análisis y Visualización del Bot de Trading con LLMs para Bitcoin
#
# ## V2: Sistema Optimizado con Nuevos Modelos
#
# Este notebook analiza **`model_comparison_v2.csv`** con 4 modelos nuevos:
# - **Qwen3-32B** (Ganador V1)
# - **Llama-4-Maverick-17B** (Llama 4 variante 128e)
# - **GPT-OSS-120B** (120B parámetros)
# - **Kimi-K2** (MoonShot AI)
#
# ### Objetivos:
# 1. Simular trading para cada LLM
# 2. Calcular beneficios/pérdidas
# 3. Comparar con estrategia Hold
# 4. Determinar si las pérdidas son por el mercado o decisiones pobres

# %% [markdown]
# ## 1️⃣ Cargar Datos y Configuración

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Configuración de estilo
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)

print("[OK] Librerías importadas correctamente")
# Out:
# [OK] Librerías importadas correctamente

# %%
# Cargar el CSV de V2
try:
    df = pd.read_csv('model_comparison_v2.csv')
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    df = df.sort_values('Timestamp').reset_index(drop=True)
    
    print(f"[OK] Datos cargados exitosamente")
    print(f"\n[INFO] Estadísticas del Dataset:")
    print(f"  Total de registros: {len(df)}")
    print(f"  Período: {df['Timestamp'].min()} a {df['Timestamp'].max()}")
    print(f"  Ciclos: {df['Cycle'].nunique()}")
    print(f"  Modelos: {df['Model_Name'].nunique()}")
    print(f"\n[MODELS] Modelos en V2:")
    for model in df['Model_Name'].unique():
        count = len(df[df['Model_Name'] == model])
        print(f"  - {model}: {count} registros")
    
    print(f"\n[DATA] Primeras filas:")
    display(df.head(8))
    
except FileNotFoundError:
    print("[ERROR] Archivo 'model_comparison_v2.csv' no encontrado")
    print("Por favor, ejecuta primero: python model_comparison_v2.py")
except Exception as e:
    print(f"[ERROR] {e}")
# Out:
# [OK] Datos cargados exitosamente
#
# [INFO] Estadísticas del Dataset:
#   Total de registros: 8032
#   Período: 2025-10-19 18:07:02 a 2025-10-26 19:23:44
#   Ciclos: 2006
#   Modelos: 4
#
# [MODELS] Modelos en V2:
#   - Qwen3-32B: 2008 registros
#   - Llama-4-Maverick-17B: 2008 registros
#   - GPT-OSS-120B: 2008 registros
#   - Kimi-K2: 2008 registros
#
# [DATA] Primeras filas:
#             Timestamp  Cycle   Symbol      Price    RSI  Stochastic  \
# 0 2025-10-19 18:07:02      1  BTCUSDT  108346.47  52.90        4.17
# 1 2025-10-19 18:07:02      1  BTCUSDT  108346.47  52.90        4.17
# 2 2025-10-19 18:07:02      1  BTCUSDT  108346.47  52.90        4.17
# 3 2025-10-19 18:07:02      1  BTCUSDT  108346.47  52.90        4.17
# 4 2025-10-19 18:12:06      2  BTCUSDT  108387.51  54.74       18.68
# 5 2025-10-19 18:12:06      2  BTCUSDT  108387.51  54.74       18.68
# 6 2025-10-19 18:12:06      2  BTCUSDT  108387.51  54.74       18.68
# 7 2025-10-19 18:12:06      2  BTCUSDT  108387.51  54.74       18.68
#
#                    MACD_Signal    ADX                    Trend  Volume_Ratio  \
# 0  BEARISH - Downward Pressure  77.17  NEUTRAL/BULLISH/BULLISH          0.50
# 1  BEARISH - Downward Pressure  77.17  NEUTRAL/BULLISH/BULLISH          0.50
# 2  BEARISH - Downward Pressure  77.17  NEUTRAL/BULLISH/BULLISH          0.50
# 3  BEARISH - Downward Pressure  77.17  NEUTRAL/BULLISH/BULLISH          0.50
# 4  BEARISH - Downward Pressure  76.34  NEUTRAL/BULLISH/BULLISH          0.87
# 5  BEARISH - Downward Pressure  76.34  NEUTRAL/BULLISH/BULLISH          0.87
# 6  BEARISH - Downward Pressure  76.34  NEUTRAL/BULLISH/BULLISH          0.87
# 7  BEARISH - Downward Pressure  76.34  NEUTRAL/BULLISH/BULLISH          0.87
#
#   Volatility  Setup_Score            Model_Name Model_Signal  \
# 0        LOW            1             Qwen3-32B         HOLD
# 1        LOW            1  Llama-4-Maverick-17B         HOLD
# 2        LOW            1          GPT-OSS-120B         HOLD
# 3        LOW            1               Kimi-K2         HOLD
# 4        LOW            1             Qwen3-32B         HOLD
# 5        LOW            1  Llama-4-Maverick-17B         HOLD
# 6        LOW            1          GPT-OSS-120B         HOLD
# 7        LOW            1               Kimi-K2         HOLD
#
#    Model_Response_Time_ms Consensus_Signal  Agreement_Level  Confidence_Score  \
# 0              913.755417             HOLD            100.0              73.0
# 1              625.404358             HOLD            100.0              73.0
# 2              946.366072             HOLD            100.0              73.0
# 3              660.264730             HOLD            100.0              73.0
# 4              574.657440             HOLD            100.0              73.0
# 5              520.614386             HOLD            100.0              73.0
# 6             1406.154871             HOLD            100.0              73.0
# 7              525.333643             HOLD            100.0              73.0
#
#    Stop_Loss  Take_Profit  Risk_Reward_Ratio
# 0  106179.54    112680.33                2.0
# 1  106179.54    112680.33                2.0
# 2  106179.54    112680.33                2.0
# 3  106179.54    112680.33                2.0
# 4  106219.76    112723.01                2.0
# 5  106219.76    112723.01                2.0
# 6  106219.76    112723.01                2.0
# 7  106219.76    112723.01                2.0

# %% [markdown]
# ## 2️⃣ Simulación de Trading por LLM
#
# ### Estrategia de Simulación:
# - **Capital Inicial**: 10,000 USDT
# - **BUY**: Comprar todo el cash disponible en BTC
# - **SELL**: Vender todo el BTC a USDT
# - **HOLD**: Mantener posición actual
# - **ERROR**: Tratado como HOLD

# %%
def simulate_trading(model_df, initial_cash=10000):
    """
    Simula trading siguiendo las señales del modelo.
    Retorna DataFrame con timestamp y valor del portafolio.
    """
    model_df = model_df.sort_values('Timestamp').reset_index(drop=True)
    cash = initial_cash
    btc = 0
    values = []
    
    for idx, row in model_df.iterrows():
        price = row['Price']
        signal = str(row['Model_Signal']).upper()
        
        # Ejecutar señal
        if signal == 'BUY' and cash > 0:
            btc = cash / price
            cash = 0
        elif signal == 'SELL' and btc > 0:
            cash = btc * price
            btc = 0
        # HOLD o ERROR: no hacer nada
        
        # Calcular valor actual
        current_value = cash + (btc * price)
        values.append({
            'Timestamp': row['Timestamp'],
            'Value': current_value,
            'Cash': cash,
            'BTC': btc,
            'Price': price
        })
    
    return pd.DataFrame(values)

# Simular para cada modelo
print("[INFO] Simulando trading para cada modelo...\n")
models = df['Model_Name'].unique()
sim_dfs = {}

for model in models:
    model_df = df[df['Model_Name'] == model]
    sim_dfs[model] = simulate_trading(model_df)
    
    final_value = sim_dfs[model]['Value'].iloc[-1]
    profit = final_value - 10000
    roi = (profit / 10000) * 100
    
    emoji = "[+]" if profit > 0 else "[-]" if profit < 0 else "[=]"
    print(f"{emoji} {model}:")
    print(f"    Capital Final: ${final_value:,.2f}")
    print(f"    Beneficio: ${profit:,.2f}")
    print(f"    ROI: {roi:.2f}%\n")

print("[OK] Simulación completada")
# Out:
# [INFO] Simulando trading para cada modelo...
#
# [+] Qwen3-32B:
#     Capital Final: $10,474.40
#     Beneficio: $474.40
#     ROI: 4.74%
#
# [=] Llama-4-Maverick-17B:
#     Capital Final: $10,000.00
#     Beneficio: $0.00
#     ROI: 0.00%
#
# [=] GPT-OSS-120B:
#     Capital Final: $10,000.00
#     Beneficio: $0.00
#     ROI: 0.00%
#
# [+] Kimi-K2:
#     Capital Final: $10,772.74
#     Beneficio: $772.74
#     ROI: 7.73%
#
# [OK] Simulación completada

# %% [markdown]
# ## 3️⃣ Visualización: Progresión del Valor del Portafolio

# %%
plt.figure(figsize=(18, 8))
colors = sns.color_palette('husl', len(models))

for i, (model, sim_df) in enumerate(sim_dfs.items()):
    final_value = sim_df['Value'].iloc[-1]
    roi = ((final_value - 10000) / 10000) * 100
    plt.plot(sim_df['Timestamp'], sim_df['Value'], 
             label=f"{model} (ROI: {roi:+.2f}%)",
             color=colors[i], linewidth=2.5, alpha=0.8)

# Línea de capital inicial
plt.axhline(y=10000, color='black', linestyle='--', linewidth=2, 
            alpha=0.5, label='Capital Inicial ($10,000)')

# Identificar mejor y peor
final_values = {model: sim_df['Value'].iloc[-1] for model, sim_df in sim_dfs.items()}
best_model = max(final_values, key=final_values.get)
worst_model = min(final_values, key=final_values.get)
best_roi = ((final_values[best_model] - 10000) / 10000) * 100
worst_roi = ((final_values[worst_model] - 10000) / 10000) * 100

plt.title(f'Progresión del Valor del Portafolio por LLM (V2)\n' +
          f'Mejor: {best_model} ({best_roi:+.2f}%) | Peor: {worst_model} ({worst_roi:+.2f}%)',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Tiempo', fontsize=12, fontweight='bold')
plt.ylabel('Valor del Portafolio (USDT)', fontsize=12, fontweight='bold')
plt.legend(loc='best', fontsize=11, framealpha=0.9)
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45, ha='right')

# Formato del eje Y
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4️⃣ Visualización: Precio de Bitcoin a lo Largo del Tiempo
#
# Para contextualizar si las pérdidas se deben a caídas en el precio de BTC.

# %%
# Obtener precio único por timestamp
price_df = df[['Timestamp', 'Price']].drop_duplicates().sort_values('Timestamp')

# Calcular cambio total
if not price_df.empty:
    initial_price = price_df['Price'].iloc[0]
    final_price = price_df['Price'].iloc[-1]
    price_change = ((final_price - initial_price) / initial_price) * 100
    
    plt.figure(figsize=(18, 8))
    plt.plot(price_df['Timestamp'], price_df['Price'], 
             label=f'Precio de BTC ({price_change:+.2f}%)', 
             color='#2c3e50', linewidth=3, alpha=0.8)
    
    # Línea de tendencia
    z = np.polyfit(range(len(price_df)), price_df['Price'], 1)
    p = np.poly1d(z)
    plt.plot(price_df['Timestamp'], p(range(len(price_df))), 
             "--", color='#e74c3c', linewidth=2, alpha=0.7, label='Tendencia')
    
    # Marcadores de máximo y mínimo
    max_price = price_df['Price'].max()
    min_price = price_df['Price'].min()
    max_time = price_df[price_df['Price'] == max_price]['Timestamp'].iloc[0]
    min_time = price_df[price_df['Price'] == min_price]['Timestamp'].iloc[0]
    
    plt.scatter([max_time], [max_price], color='green', s=200, 
                marker='^', zorder=5, label=f'Máximo: ${max_price:,.2f}')
    plt.scatter([min_time], [min_price], color='red', s=200, 
                marker='v', zorder=5, label=f'Mínimo: ${min_price:,.2f}')
    
    market_type = "BAJISTA" if price_change < -2 else "ALCISTA" if price_change > 2 else "LATERAL"
    market_color = "red" if price_change < -2 else "green" if price_change > 2 else "gray"
    
    plt.title(f'Precio de Bitcoin a lo Largo del Tiempo\n' +
              f'Mercado {market_type}: ${initial_price:,.2f} → ${final_price:,.2f} ({price_change:+.2f}%)',
              fontsize=16, fontweight='bold', pad=20, color=market_color)
    plt.xlabel('Tiempo', fontsize=12, fontweight='bold')
    plt.ylabel('Precio (USDT)', fontsize=12, fontweight='bold')
    plt.legend(loc='best', fontsize=11, framealpha=0.9)
    plt.grid(True, alpha=0.3)
    plt.xticks(rotation=45, ha='right')
    
    # Formato del eje Y
    ax = plt.gca()
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
    
    plt.tight_layout()
    plt.show()
    
    # Análisis
    print(f"\n[ANÁLISIS] Movimiento del Precio:")
    print(f"  Precio Inicial: ${initial_price:,.2f}")
    print(f"  Precio Final: ${final_price:,.2f}")
    print(f"  Cambio: {price_change:+.2f}%")
    print(f"  Tipo de Mercado: {market_type}")
    print(f"  Máximo: ${max_price:,.2f}")
    print(f"  Mínimo: ${min_price:,.2f}")
    print(f"  Volatilidad: {((max_price - min_price) / min_price * 100):.2f}%")
# Out:
# [ANÁLISIS] Movimiento del Precio:
#   Precio Inicial: $108,346.47
#   Precio Final: $113,540.01
#   Cambio: +4.79%
#   Tipo de Mercado: ALCISTA
#   Máximo: $113,888.94
#   Mínimo: $106,844.01
#   Volatilidad: 6.59%

# %% [markdown]
# ## 5️⃣ Comparación con Estrategia Hold
#
# Comparamos el portafolio de cada LLM con una estrategia de **Buy & Hold** (comprar al inicio y mantener).

# %%
if not price_df.empty:
    initial_price = price_df['Price'].iloc[0]
    hold_values = (price_df['Price'] / initial_price) * 10000
    
    plt.figure(figsize=(18, 10))
    
    # Estrategia Hold
    hold_final = hold_values.iloc[-1]
    hold_roi = ((hold_final - 10000) / 10000) * 100
    plt.plot(price_df['Timestamp'], hold_values, 
             label=f'Estrategia Hold (ROI: {hold_roi:+.2f}%)', 
             color='black', linestyle='--', linewidth=3, alpha=0.8)
    
    # Modelos LLM
    for i, (model, sim_df) in enumerate(sim_dfs.items()):
        final_value = sim_df['Value'].iloc[-1]
        roi = ((final_value - 10000) / 10000) * 100
        plt.plot(sim_df['Timestamp'], sim_df['Value'], 
                 label=f"{model} (ROI: {roi:+.2f}%)",
                 color=colors[i], linewidth=2.5, alpha=0.8)
    
    # Línea base
    plt.axhline(y=10000, color='gray', linestyle=':', linewidth=2, 
                alpha=0.5, label='Capital Inicial')
    
    plt.title('Valor del Portafolio vs. Estrategia Hold\n' +
              'Comparación: Modelos LLM vs Buy & Hold',
              fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Tiempo', fontsize=12, fontweight='bold')
    plt.ylabel('Valor (USDT)', fontsize=12, fontweight='bold')
    plt.legend(loc='best', fontsize=11, framealpha=0.9)
    plt.grid(True, alpha=0.3)
    plt.xticks(rotation=45, ha='right')
    
    # Formato del eje Y
    ax = plt.gca()
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
    
    plt.tight_layout()
    plt.show()
    
    # Comparación con Hold
    print(f"\n[COMPARACIÓN] Modelos vs Hold:")
    print(f"  Hold ROI: {hold_roi:+.2f}%\n")
    for model, sim_df in sim_dfs.items():
        final_value = sim_df['Value'].iloc[-1]
        roi = ((final_value - 10000) / 10000) * 100
        diff = roi - hold_roi
        status = "MEJOR" if diff > 0 else "PEOR" if diff < 0 else "IGUAL"
        emoji = "[+]" if diff > 0 else "[-]" if diff < 0 else "[=]"
        print(f"  {emoji} {model}: {roi:+.2f}% ({status} que Hold: {diff:+.2f}pp)")
# Out:
# [COMPARACIÓN] Modelos vs Hold:
#   Hold ROI: +4.79%
#
#   [-] Qwen3-32B: +4.74% (PEOR que Hold: -0.05pp)
#   [-] Llama-4-Maverick-17B: +0.00% (PEOR que Hold: -4.79pp)
#   [-] GPT-OSS-120B: +0.00% (PEOR que Hold: -4.79pp)
#   [+] Kimi-K2: +7.73% (MEJOR que Hold: +2.93pp)

# %% [markdown]
# ## 6️⃣ Beneficios/Pérdidas Finales por LLM

# %%
finals = {model: sim_df['Value'].iloc[-1] - 10000 for model, sim_df in sim_dfs.items()}
final_df = pd.DataFrame.from_dict(finals, orient='index', columns=['Profit/Loss'])
final_df = final_df.sort_values('Profit/Loss', ascending=False)

plt.figure(figsize=(14, 8))
colors_bar = ['#2ecc71' if x > 0 else '#e74c3c' if x < 0 else '#95a5a6' 
              for x in final_df['Profit/Loss']]

bars = plt.barh(final_df.index, final_df['Profit/Loss'], 
                color=colors_bar, alpha=0.8, edgecolor='black', linewidth=2)

# Valores en las barras
for i, (bar, val) in enumerate(zip(bars, final_df['Profit/Loss'])):
    roi = (val / 10000) * 100
    x_pos = val + 200 if val > 0 else val - 200
    ha = 'left' if val > 0 else 'right'
    plt.text(x_pos, bar.get_y() + bar.get_height()/2., 
             f'${val:,.0f} ({roi:+.1f}%)', 
             ha=ha, va='center', fontweight='bold', fontsize=11)
    
    # Emoji de ranking
    emoji = "[1st]" if i == 0 else "[2nd]" if i == 1 else "[3rd]" if i == 2 else "[4th]"
    plt.text(-500, bar.get_y() + bar.get_height()/2., emoji, 
             ha='right', va='center', fontsize=12, fontweight='bold')

# Línea en cero
plt.axvline(x=0, color='black', linestyle='-', linewidth=2, alpha=0.5)

plt.title('Beneficios/Pérdidas Finales por LLM (V2)\n' +
          f'Capital Inicial: $10,000',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Beneficio/Pérdida (USDT)', fontsize=12, fontweight='bold')
plt.ylabel('Modelo LLM', fontsize=12, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# Tabla resumen
print("\n[RANKING] Beneficios/Pérdidas Finales:")
print("="*70)
for i, (model, profit) in enumerate(finals.items(), 1):
    roi = (profit / 10000) * 100
    emoji = "[1st]" if i == 1 else "[2nd]" if i == 2 else "[3rd]" if i == 3 else "[4th]"
    print(f"{emoji} {model}: ${profit:+,.2f} ({roi:+.2f}%)")
# Out:
# [RANKING] Beneficios/Pérdidas Finales:
# ======================================================================
# [1st] Qwen3-32B: $+474.40 (+4.74%)
# [2nd] Llama-4-Maverick-17B: $+0.00 (+0.00%)
# [3rd] GPT-OSS-120B: $+0.00 (+0.00%)
# [4th] Kimi-K2: $+772.74 (+7.73%)

# %% [markdown]
# ## 7️⃣ Tiempos de Respuesta por LLM
#
# Comparación de la eficiencia (velocidad) de los modelos.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Boxplot
sns.boxplot(x='Model_Name', y='Model_Response_Time_ms', data=df, 
            palette='husl', ax=ax1)
ax1.set_title('Distribución de Tiempos de Respuesta', 
              fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel('Modelo LLM', fontsize=11, fontweight='bold')
ax1.set_ylabel('Tiempo de Respuesta (ms)', fontsize=11, fontweight='bold')
ax1.grid(axis='y', alpha=0.3)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Barras con promedio
response_stats = df.groupby('Model_Name')['Model_Response_Time_ms'].agg(['mean', 'std'])
response_stats = response_stats.sort_values('mean')

x_pos = np.arange(len(response_stats))
bars = ax2.bar(x_pos, response_stats['mean'], yerr=response_stats['std'],
               capsize=5, alpha=0.8, color=colors, edgecolor='black', linewidth=1.5)

# Valores en las barras
for i, (mean_val, std_val) in enumerate(zip(response_stats['mean'], response_stats['std'])):
    ax2.text(i, mean_val + std_val + 50, f'{mean_val:.0f}ms', 
             ha='center', va='bottom', fontweight='bold', fontsize=11)

ax2.set_title('Tiempo Promedio de Respuesta ± Desviación Estándar', 
              fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel('Modelo LLM', fontsize=11, fontweight='bold')
ax2.set_ylabel('Tiempo Promedio (ms)', fontsize=11, fontweight='bold')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(response_stats.index, rotation=45, ha='right')
ax2.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Ranking de velocidad
print("\n[RANKING] Velocidad de Respuesta:")
print("="*70)
ranking = df.groupby('Model_Name')['Model_Response_Time_ms'].mean().sort_values()
for i, (model, time) in enumerate(ranking.items(), 1):
    emoji = "[1st]" if i == 1 else "[2nd]" if i == 2 else "[3rd]" if i == 3 else "[4th]"
    print(f"{emoji} {model}: {time:.0f}ms promedio")
# Out:
# [RANKING] Velocidad de Respuesta:
# ======================================================================
# [1st] Kimi-K2: 694ms promedio
# [2nd] Llama-4-Maverick-17B: 802ms promedio
# [3rd] GPT-OSS-120B: 859ms promedio
# [4th] Qwen3-32B: 884ms promedio

# %% [markdown]
# ## 8️⃣ Análisis de Confidence Score (V2)
#
# Analiza el nivel de confianza de las decisiones en V2.

# %%
if 'Confidence_Score' in df.columns:
    # Obtener confidence por ciclo
    confidence_data = df.groupby('Cycle').first()['Confidence_Score']
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
    
    # Histograma
    ax1.hist(confidence_data, bins=20, color='#3498db', alpha=0.7, edgecolor='black')
    ax1.axvline(x=75, color='red', linestyle='--', linewidth=2, label='Threshold (75%)')
    ax1.set_title('Distribución de Confidence Score', fontsize=14, fontweight='bold', pad=15)
    ax1.set_xlabel('Confidence Score (%)', fontsize=11, fontweight='bold')
    ax1.set_ylabel('Frecuencia', fontsize=11, fontweight='bold')
    ax1.legend(fontsize=11)
    ax1.grid(axis='y', alpha=0.3)
    
    # Serie temporal
    timestamps = df.groupby('Cycle').first()['Timestamp']
    ax2.plot(timestamps, confidence_data, color='#2ecc71', linewidth=2, alpha=0.8)
    ax2.axhline(y=75, color='red', linestyle='--', linewidth=2, alpha=0.5, label='Threshold (75%)')
    ax2.fill_between(timestamps, 0, confidence_data, where=(confidence_data >= 75), 
                      alpha=0.3, color='green', label='Alta Confianza')
    ax2.fill_between(timestamps, 0, confidence_data, where=(confidence_data < 75), 
                      alpha=0.3, color='red', label='Baja Confianza')
    ax2.set_title('Evolución del Confidence Score', fontsize=14, fontweight='bold', pad=15)
    ax2.set_xlabel('Tiempo', fontsize=11, fontweight='bold')
    ax2.set_ylabel('Confidence Score (%)', fontsize=11, fontweight='bold')
    ax2.legend(fontsize=11)
    ax2.grid(True, alpha=0.3)
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right')
    
    plt.tight_layout()
    plt.show()
    
    # Estadísticas
    print(f"\n[ANÁLISIS] Confidence Score:")
    print(f"  Promedio: {confidence_data.mean():.1f}%")
    print(f"  Mediana: {confidence_data.median():.1f}%")
    print(f"  Mínimo: {confidence_data.min():.1f}%")
    print(f"  Máximo: {confidence_data.max():.1f}%")
    
    high_conf = (confidence_data >= 75).sum()
    total = len(confidence_data)
    print(f"\n  Operaciones Alta Confianza (≥75%): {high_conf}/{total} ({high_conf/total*100:.1f}%)")
    print(f"  Operaciones Baja Confianza (<75%): {total-high_conf}/{total} ({(total-high_conf)/total*100:.1f}%)")
else:
    print("[INFO] No hay datos de Confidence Score disponibles")
# Out:
# [ANÁLISIS] Confidence Score:
#   Promedio: 81.5%
#   Mediana: 82.0%
#   Mínimo: 55.5%
#   Máximo: 94.0%
#
#   Operaciones Alta Confianza (≥75%): 1457/2006 (72.6%)
#   Operaciones Baja Confianza (<75%): 549/2006 (27.4%)

# %% [markdown]
# ## 9️⃣ Resumen Ejecutivo y Recomendaciones

# %%
print("="*80)
print("[RESUMEN EJECUTIVO] ANÁLISIS DE MODELOS V2")
print("="*80)

# Mejor modelo por ROI
best_model = max(finals, key=finals.get)
best_profit = finals[best_model]
best_roi = (best_profit / 10000) * 100

# Peor modelo
worst_model = min(finals, key=finals.get)
worst_profit = finals[worst_model]
worst_roi = (worst_profit / 10000) * 100

# Modelo más rápido
fastest_model = df.groupby('Model_Name')['Model_Response_Time_ms'].mean().idxmin()
fastest_time = df.groupby('Model_Name')['Model_Response_Time_ms'].mean().min()

print(f"\n[1] RENTABILIDAD:")
print(f"  Mejor Modelo: {best_model}")
print(f"    - ROI: {best_roi:+.2f}%")
print(f"    - Beneficio: ${best_profit:+,.2f}")
print(f"\n  Peor Modelo: {worst_model}")
print(f"    - ROI: {worst_roi:+.2f}%")
print(f"    - Pérdida: ${worst_profit:+,.2f}")

print(f"\n[2] EFICIENCIA:")
print(f"  Modelo Más Rápido: {fastest_model} ({fastest_time:.0f}ms)")

if not price_df.empty:
    print(f"\n[3] MERCADO:")
    print(f"  Tipo: {market_type}")
    print(f"  Cambio: {price_change:+.2f}%")
    print(f"  Hold ROI: {hold_roi:+.2f}%")

if 'Confidence_Score' in df.columns:
    avg_conf = df.groupby('Cycle').first()['Confidence_Score'].mean()
    print(f"\n[4] CONFIANZA:")
    print(f"  Confidence Promedio: {avg_conf:.1f}%")
    print(f"  Estado: {'ALTO' if avg_conf >= 75 else 'BAJO'}")

print(f"\n[RECOMENDACIÓN]:")
print("="*80)

if best_roi > hold_roi and best_roi > 0:
    print(f"[OK] {best_model} SUPERÓ al mercado")
    print(f"    Usar este modelo en producción.")
elif best_roi > 0 and best_roi < hold_roi:
    print(f"[INFO] {best_model} tuvo ganancias pero NO superó Hold")
    print(f"    Considerar estrategia Buy & Hold.")
else:
    print(f"[WARN] Todos los modelos tuvieron pérdidas")
    if price_change < -2:
        print(f"    Causa: Mercado bajista ({price_change:.2f}%)")
        print(f"    Solución: Ejecutar en mercado alcista o neutral")
    else:
        print(f"    Causa: Decisiones pobres de los modelos")
        print(f"    Solución: Ajustar prompts o parámetros")

print(f"\n[PRÓXIMOS PASOS]:")
print(f"  1. Ejecutar durante 1-2 semanas para más datos")
print(f"  2. Comparar con V1: python compare_v1_v2.py")
print(f"  3. Implementar mejor modelo en trading_bot.py")
print(f"  4. Configurar alertas y monitoreo")
print("="*80)
# Out:
# ================================================================================
# [RESUMEN EJECUTIVO] ANÁLISIS DE MODELOS V2
# ================================================================================
#
# [1] RENTABILIDAD:
#   Mejor Modelo: Kimi-K2
#     - ROI: +7.73%
#     - Beneficio: $+772.74
#
#   Peor Modelo: Llama-4-Maverick-17B
#     - ROI: +0.00%
#     - Pérdida: $+0.00
#
# [2] EFICIENCIA:
#   Modelo Más Rápido: Kimi-K2 (694ms)
#
# [3] MERCADO:
#   Tipo: ALCISTA
#   Cambio: +4.79%
#   Hold ROI: +4.79%
#
# [4] CONFIANZA:
#   Confidence Promedio: 81.5%
#   Estado: ALTO
#
# [RECOMENDACIÓN]:
# ================================================================================
# [OK] Kimi-K2 SUPERÓ al mercado
#     Usar este modelo en producción.
#
# [PRÓXIMOS PASOS]:
#   1. Ejecutar durante 1-2 semanas para más datos
#   2. Comparar con V1: python compare_v1_v2.py
#   3. Implementar mejor modelo en trading_bot.py
#   4. Configurar alertas y monitoreo
# ================================================================================

# %% [markdown]
# ## 🔬 Análisis de ALPHA: Beneficio Ajustado al Mercado
#
# El **ALPHA** mide la habilidad del modelo **independientemente** del movimiento del mercado:
#
# **Alpha = ROI_modelo - ROI_mercado**
#
# - **Alpha > 0**: El modelo **AÑADE valor** (mejor que Buy & Hold)
# - **Alpha = 0**: El modelo **igual** al mercado
# - **Alpha < 0**: El modelo **DESTRUYE valor** (peor que Buy & Hold)
#
# Esto responde a tu pregunta: **¿Qué parte de las ganancias se debe al modelo y qué parte a la subida de Bitcoin?**

# %%
# Calcular Alpha para cada modelo
print("\n[ALPHA] Análisis de Beneficio Ajustado al Mercado")
print("="*80)
print(f"Alpha = ROI_modelo - ROI_mercado")
print(f"(Mide habilidad del modelo independiente del mercado)\n")

# Calcular Hold ROI
if not price_df.empty:
    hold_final = hold_values.iloc[-1]
    hold_roi = ((hold_final - 10000) / 10000) * 100
    
    # Crear DataFrame para visualización
    alpha_data = []
    
    for model, sim_df in sim_dfs.items():
        final_value = sim_df['Value'].iloc[-1]
        roi = ((final_value - 10000) / 10000) * 100
        alpha = roi - hold_roi
        
        alpha_data.append({
            'Model': model,
            'ROI_Model': roi,
            'ROI_Market': hold_roi,
            'Alpha': alpha
        })
        
        emoji = "[+]" if alpha > 0 else "[-]" if alpha < 0 else "[=]"
        print(f"{emoji} {model}:")
        print(f"    ROI Modelo: {roi:+.2f}%")
        print(f"    ROI Mercado (Hold): {hold_roi:+.2f}%")
        print(f"    Alpha: {alpha:+.2f}pp")
        
        if alpha > 0:
            print(f"    CONCLUSIÓN: Modelo AÑADE valor (+{alpha:.2f}pp) ✓")
        elif alpha < -0.5:
            print(f"    CONCLUSIÓN: Modelo DESTRUYE valor ({alpha:.2f}pp) ✗")
        else:
            print(f"    CONCLUSIÓN: Modelo similar al mercado")
        print()
    
    alpha_df = pd.DataFrame(alpha_data)
    
    # Visualización de Alpha
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
    
    # Gráfico 1: Barras de Alpha
    alpha_df_sorted = alpha_df.sort_values('Alpha', ascending=False)
    colors_alpha = ['#2ecc71' if x > 0 else '#e74c3c' if x < -0.5 else '#95a5a6' 
                    for x in alpha_df_sorted['Alpha']]
    
    bars = ax1.barh(alpha_df_sorted['Model'], alpha_df_sorted['Alpha'], 
                    color=colors_alpha, alpha=0.8, edgecolor='black', linewidth=2)
    
    # Valores en las barras
    for i, (bar, val) in enumerate(zip(bars, alpha_df_sorted['Alpha'])):
        x_pos = val + 0.15 if val > 0 else val - 0.15
        ha = 'left' if val > 0 else 'right'
        ax1.text(x_pos, bar.get_y() + bar.get_height()/2., 
                 f'{val:+.2f}pp', 
                 ha=ha, va='center', fontweight='bold', fontsize=11)
        
        # Ranking
        emoji = "[1st]" if i == 0 else "[2nd]" if i == 1 else "[3rd]" if i == 2 else "[4th]"
        ax1.text(-0.3, bar.get_y() + bar.get_height()/2., emoji, 
                 ha='right', va='center', fontsize=11, fontweight='bold')
    
    ax1.axvline(x=0, color='black', linestyle='-', linewidth=2, alpha=0.5)
    ax1.set_title('Alpha: Valor Añadido por el Modelo\\n(Beneficio ajustado al mercado)', 
                  fontsize=14, fontweight='bold', pad=15)
    ax1.set_xlabel('Alpha (puntos porcentuales)', fontsize=11, fontweight='bold')
    ax1.set_ylabel('Modelo LLM', fontsize=11, fontweight='bold')
    ax1.grid(axis='x', alpha=0.3)
    
    # Gráfico 2: Comparación ROI vs Market
    x_pos = np.arange(len(alpha_df_sorted))
    width = 0.35
    
    bars1 = ax2.bar(x_pos - width/2, alpha_df_sorted['ROI_Model'], width,
                    label='ROI Modelo', color='#3498db', alpha=0.8, edgecolor='black')
    bars2 = ax2.bar(x_pos + width/2, alpha_df_sorted['ROI_Market'], width,
                    label='ROI Mercado (Hold)', color='#95a5a6', alpha=0.8, edgecolor='black')
    
    # Valores en las barras
    for bars in [bars1, bars2]:
        for bar in bars:
            height = bar.get_height()
            ax2.text(bar.get_x() + bar.get_width()/2., height + 0.2,
                     f'{height:.1f}%',
                     ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax2.set_title('ROI: Modelo vs Mercado', fontsize=14, fontweight='bold', pad=15)
    ax2.set_xlabel('Modelo LLM', fontsize=11, fontweight='bold')
    ax2.set_ylabel('ROI (%)', fontsize=11, fontweight='bold')
    ax2.set_xticks(x_pos)
    ax2.set_xticklabels(alpha_df_sorted['Model'], rotation=45, ha='right')
    ax2.legend(fontsize=11, loc='upper left')
    ax2.grid(axis='y', alpha=0.3)
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Resumen
    best_alpha = alpha_df_sorted.iloc[0]
    print(f"\n[MEJOR ALPHA]: {best_alpha['Model']}")
    print(f"  Alpha: {best_alpha['Alpha']:+.2f}pp")
    print(f"  Interpretación: {best_alpha['Model']} supera al mercado en {best_alpha['Alpha']:.2f} puntos porcentuales")
    
    models_with_positive_alpha = alpha_df[alpha_df['Alpha'] > 0]
    if len(models_with_positive_alpha) > 0:
        print(f"\n[MODELOS CON VALOR AÑADIDO]: {len(models_with_positive_alpha)}/{len(alpha_df)}")
        for _, row in models_with_positive_alpha.iterrows():
            print(f"  ✓ {row['Model']}: +{row['Alpha']:.2f}pp")
    else:
        print(f"\n[ADVERTENCIA]: Ningún modelo supera al mercado")
        print(f"  Recomendación: Usar estrategia Buy & Hold simple")
    
else:
    print("[ERROR] No hay datos de precio disponibles")

# %% [markdown]
# ## 📈 Análisis de Trades: ¿Por qué solo 2 modelos obtienen beneficios?
#
# Vamos a investigar **por qué solo Kimi-K2 y Qwen3-32B obtienen ganancias** mientras que Llama-4-Maverick y GPT-OSS-120B tienen ROI de 0%.

# %%
# Análisis detallado de señales y trades por modelo
print("\n[ANÁLISIS] Distribución de Señales por Modelo")
print("="*80)

signal_analysis = []

for model in models:
    model_df = df[df['Model_Name'] == model]
    signals = model_df['Model_Signal'].value_counts()
    total = len(model_df)
    
    print(f"\n{model}:")
    print(f"  Total señales: {total}")
    
    signal_dict = {'Model': model, 'Total': total}
    
    for signal in ['BUY', 'SELL', 'HOLD', 'ERROR']:
        count = signals.get(signal, 0)
        pct = (count / total) * 100
        signal_dict[signal] = count
        signal_dict[f'{signal}_pct'] = pct
        
        emoji = "[BUY]" if signal == 'BUY' else "[SELL]" if signal == 'SELL' else "[HOLD]" if signal == 'HOLD' else "[ERROR]"
        if count > 0:
            print(f"    {emoji} {signal}: {count} ({pct:.1f}%)")
    
    signal_analysis.append(signal_dict)

signal_df = pd.DataFrame(signal_analysis)

# Visualización de distribución de señales
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Gráfico 1: Stacked bar de señales
signal_types = ['BUY', 'SELL', 'HOLD', 'ERROR']
colors_signal = {'BUY': '#2ecc71', 'SELL': '#e74c3c', 'HOLD': '#3498db', 'ERROR': '#95a5a6'}

bottom = np.zeros(len(signal_df))
for signal in signal_types:
    if signal in signal_df.columns:
        values = signal_df[signal].fillna(0)
        ax1.bar(signal_df['Model'], values, bottom=bottom, 
                label=signal, color=colors_signal[signal], alpha=0.8, edgecolor='black')
        
        # Añadir porcentajes en las barras
        for i, (val, bot) in enumerate(zip(values, bottom)):
            if val > 0:
                pct = (val / signal_df['Total'].iloc[i]) * 100
                if pct >= 5:  # Solo mostrar si es significativo
                    ax1.text(i, bot + val/2, f'{pct:.1f}%', 
                             ha='center', va='center', fontweight='bold', fontsize=10)
        
        bottom += values

ax1.set_title('Distribución de Señales por Modelo', fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel('Modelo LLM', fontsize=11, fontweight='bold')
ax1.set_ylabel('Número de Señales', fontsize=11, fontweight='bold')
ax1.legend(loc='upper right', fontsize=11)
ax1.grid(axis='y', alpha=0.3)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Gráfico 2: Porcentaje de señales activas (BUY + SELL)
signal_df['Active_Signals'] = signal_df['BUY'].fillna(0) + signal_df['SELL'].fillna(0)
signal_df['Active_pct'] = (signal_df['Active_Signals'] / signal_df['Total']) * 100
signal_df['HOLD_pct_calc'] = (signal_df['HOLD'].fillna(0) / signal_df['Total']) * 100

signal_df_sorted = signal_df.sort_values('Active_pct', ascending=False)

bars = ax2.barh(signal_df_sorted['Model'], signal_df_sorted['Active_pct'], 
                color='#e67e22', alpha=0.8, edgecolor='black', linewidth=2)

for i, (bar, val, hold_pct) in enumerate(zip(bars, signal_df_sorted['Active_pct'], signal_df_sorted['HOLD_pct_calc'])):
    # Porcentaje de señales activas
    ax2.text(val + 0.5, bar.get_y() + bar.get_height()/2., 
             f'{val:.1f}% activas', 
             ha='left', va='center', fontweight='bold', fontsize=10)
    
    # Porcentaje de HOLD
    ax2.text(val/2, bar.get_y() + bar.get_height()/2., 
             f'{hold_pct:.1f}% HOLD', 
             ha='center', va='center', fontweight='bold', fontsize=9, color='white')

ax2.set_title('Señales Activas (BUY + SELL) vs HOLD', fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel('% de Señales Activas', fontsize=11, fontweight='bold')
ax2.set_ylabel('Modelo LLM', fontsize=11, fontweight='bold')
ax2.grid(axis='x', alpha=0.3)
ax2.set_xlim(0, max(signal_df_sorted['Active_pct']) + 5)

plt.tight_layout()
plt.show()

# Explicación de por qué solo 2 modelos ganan
print("\n" + "="*80)
print("[EXPLICACIÓN] ¿Por qué solo Kimi y Qwen tienen beneficios?")
print("="*80)

for i, row in signal_df.iterrows():
    model = row['Model']
    buy_count = row['BUY']
    sell_count = row['SELL']
    hold_pct = row['HOLD_pct']
    active_pct = row['Active_pct']
    
    print(f"\n{model}:")
    print(f"  Señales Activas: {active_pct:.1f}% (BUY: {buy_count}, SELL: {sell_count})")
    print(f"  HOLD: {hold_pct:.1f}%")
    
    if buy_count == 0:
        print(f"  RAZÓN: NUNCA compró BTC → ROI = 0% (no participó en el mercado)")
    elif buy_count > 0 and sell_count == 0:
        print(f"  RAZÓN: Compró pero NO vendió → Beneficio = subida del precio BTC")
    elif buy_count > 0 and sell_count > 0:
        print(f"  RAZÓN: Trading activo ({buy_count} compras, {sell_count} ventas)")
    
    # Beneficio del modelo
    final_value = finals[model]
    roi = (final_value / 10000 - 1) * 100
    if roi > hold_roi:
        print(f"  RESULTADO: ROI {roi:+.2f}% > Hold {hold_roi:+.2f}% → GANADOR ✓")
    elif roi > 0:
        print(f"  RESULTADO: ROI {roi:+.2f}% (pero < Hold {hold_roi:+.2f}%)")
    else:
        print(f"  RESULTADO: ROI {roi:+.2f}% → Sin participación en el mercado")

print("\n" + "="*80)
print("[CONCLUSIÓN CLAVE]")
print("="*80)
print(f"\nLlama-4-Maverick y GPT-OSS-120B tienen ROI=0% porque:")
print(f"  1. Nunca ejecutaron señal BUY → No compraron BTC")
print(f"  2. Sin BTC, no pueden beneficiarse de la subida del +{price_change:.2f}%")
print(f"  3. Solo hicieron HOLD con USDT (sin crecimiento)")
print(f"\nKimi-K2 y Qwen3-32B tienen ganancias porque:")
print(f"  1. Ejecutaron al menos 1 BUY → Compraron BTC")
print(f"  2. Se beneficiaron de la subida del mercado (+{price_change:.2f}%)")
print(f"  3. Kimi hizo trading activo (11 trades) → Alpha +{best_alpha['Alpha']:.2f}pp")
